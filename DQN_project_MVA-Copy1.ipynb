# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization,Dropout,Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject on Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# The function acts prepares the move to the next state of the system by returning the next action to perform.
#
# The next action to perform is either chosen according to previously defined policy - exploitation step - (by calling the method learned_act) or by exploring a random action with probability epsilon -exploration step-.
#
# The random exploration performed with probability epsilon allows the agent to deviate from the previously defined policy thus giving it the possibility to improve its performance.
#
# Once a policy with high Q-value has been found, the method gives us the possibility to stop the exploration and only perform exploitation by setting train to False.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        # CODAGE RVB DE CHAQUE POINT, un vecteur de grid_size ligne contenant en entree une matrice de gridsize*3, codage rvb
        #de chaque case de chaque ligne
        b = np.zeros((self.grid_size,self.grid_size,3))+128 #everything starts in grey
        b[self.board>0,0] = 256 # bonus in red
        b[self.board < 0, 2] = 256  #malus in blue
        b[self.x,self.y,:]=256 #position cursor in white
        b[-2:,:,:]=0  # border in black
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1 #modification made here

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3: #extremité droite de la grille
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1: 
            if self.x == 2: #extrémité gauche de la grille, l'agent réalise la seule action possible en x quand il tire 01
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0 #must be set to zero, because cheese eaten disappears
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:] # vision de 2 cases

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2) #random position of cheeses
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2) #random position of traps
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1 #modif here
        self.board[self.x,self.y] = 0  #no starting bonus or malus
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        # gives new state of board along with previous position array

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        #we visualise new state around the new position
        #the new position corresponds to the middle array on middle line and right ie see examples below
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train= 10 # set small when debugging
epochs_test= 10# set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

def display2(name):
    #we get an html error with previous function so we define another one to read video
    # Create a VideoCapture object and read from input file 
    cap = cv2.VideoCapture('random0.mp4') 

    # Check if camera opened successfully 
    if (cap.isOpened()== False):  
      print("Error opening video  file") 

    # Read until video is completed 
    while(cap.isOpened()): 

      # Capture frame-by-frame 
      ret, frame = cap.read() 
      if ret == True: 

        # Display the resulting frame 
        cv2.imshow('Frame', frame) 

        # Press Q on keyboard to  exit 
        if cv2.waitKey(25) & 0xFF == ord('q'): 
          break

      # Break the loop 
      else:  
        break

    # When everything done, release  
    # the video capture object 
    cap.release() 

    # Closes all the frames 
    cv2.destroyAllWindows() 
    return

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# The board array describes the entire state of the N*N board, it keeps track of where the bonuses (cheese) are located and where  the traps are on the board (-1). All other positions with neither trap nor reward are marked with 0. To sum up the board array keeps track of the rewards on each square of the board. It gets updated (with 0) by the method act as the rewards are taken.
#
# The position array is just a representation of where the rat is in the board and the invalid positions.  Since the grid is of length N+4, the first and last two columns and lines are invalid positions for the rat and are thus marked with -1. The square on which the rat stands is set at 1, the invalid frontier values of the board are set at -1 and the rest is set at 0. After act is called position becomes where the rat was before moving.
#
# position[i, j] indicates whether the agent is at $(i,j)$ or not.
#
# board[i, j] indicates the state of the board at $(i,j)$ - whether there is cheese, poison, or nothing.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        action = np.random.randint(0,4)
        if action==0:
            if s[3,2,1]==-1:
                return 1
            return 0
        elif action ==1:
            if s[1,2,1]==-1:
                return 0
            return 1
        elif action ==2:
            if s[2,3,1]==-1:
                return 3
            return 2
        elif action ==3:
            if s[2,1,1]==-1:
                return 2
            return 3

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix='random'):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        
             # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will end
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            #loss = agent.reinforce(prev_state, state,  action, reward, game_over)

   
        
            ##### FILL IN HERE
        
        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))
    return

# %% [markdown]
# #### Answer
# Here we play with the random agent.
#
# We compute the average score on the elapsed epochs as we test the model and go through several test epochs.
#
# We see that is between -5 and -4 for the random agent.

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()
epochs_test = 50
test(agent,env,epochs_test,prefix='random')
#HTML(display_videos('random0.mp4'))
display2('random0.mp4')
# Out:
# Win/lose count 9.5/19.0. Average score (-9.5)
# Win/lose count 9.5/12.0. Average score (-6.0)
# Win/lose count 6.5/12.0. Average score (-5.833333333333333)
# Win/lose count 3.0/16.0. Average score (-7.625)
# Win/lose count 8.0/11.0. Average score (-6.7)
# Win/lose count 8.0/9.0. Average score (-5.75)
# Win/lose count 14.0/17.0. Average score (-5.357142857142857)
# Win/lose count 11.0/17.0. Average score (-5.4375)
# Win/lose count 9.0/10.0. Average score (-4.944444444444445)
# Win/lose count 8.0/13.0. Average score (-4.95)
# Win/lose count 13.0/18.0. Average score (-4.954545454545454)
# Win/lose count 10.0/11.0. Average score (-4.625)
# Win/lose count 10.0/15.0. Average score (-4.653846153846154)
# Win/lose count 12.5/11.0. Average score (-4.214285714285714)
# Win/lose count 9.5/16.0. Average score (-4.366666666666666)
# Win/lose count 12.0/18.0. Average score (-4.46875)
# Win/lose count 9.0/18.0. Average score (-4.735294117647059)
# Win/lose count 10.0/14.0. Average score (-4.694444444444445)
# Win/lose count 5.5/10.0. Average score (-4.684210526315789)
# Win/lose count 10.5/14.0. Average score (-4.625)
# Win/lose count 6.5/9.0. Average score (-4.523809523809524)
# Win/lose count 7.0/17.0. Average score (-4.7727272727272725)
# Win/lose count 9.0/17.0. Average score (-4.913043478260869)
# Win/lose count 8.0/12.0. Average score (-4.875)
# Win/lose count 12.0/9.0. Average score (-4.56)
# Win/lose count 12.5/19.0. Average score (-4.634615384615385)
# Win/lose count 11.0/18.0. Average score (-4.722222222222222)
# Win/lose count 6.0/17.0. Average score (-4.946428571428571)
# Win/lose count 12.0/17.0. Average score (-4.948275862068965)
# Win/lose count 9.5/21.0. Average score (-5.166666666666667)
# Win/lose count 6.0/14.0. Average score (-5.258064516129032)
# Win/lose count 7.5/18.0. Average score (-5.421875)
# Win/lose count 13.5/13.0. Average score (-5.242424242424242)
# Win/lose count 13.5/13.0. Average score (-5.073529411764706)
# Win/lose count 11.0/18.0. Average score (-5.128571428571429)
# Win/lose count 7.0/15.0. Average score (-5.208333333333333)
# Win/lose count 9.5/9.0. Average score (-5.054054054054054)
# Win/lose count 9.5/17.0. Average score (-5.118421052631579)
# Win/lose count 9.0/21.0. Average score (-5.294871794871795)
# Win/lose count 9.5/11.0. Average score (-5.2)
# Win/lose count 7.0/17.0. Average score (-5.317073170731708)
# Win/lose count 11.0/14.0. Average score (-5.261904761904762)
# Win/lose count 6.5/2.0. Average score (-5.034883720930233)
# Win/lose count 9.5/15.0. Average score (-5.045454545454546)
# Win/lose count 9.5/15.0. Average score (-5.055555555555555)
# Win/lose count 9.5/16.0. Average score (-5.086956521739131)
# Win/lose count 14.0/15.0. Average score (-5.0)
# Win/lose count 10.0/15.0. Average score (-5.0)
# Win/lose count 6.5/8.0. Average score (-4.928571428571429)
# Win/lose count 8.5/11.0. Average score (-4.88)
# Final score: -4.88

# %%
display2('random9.mp4')

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# ### Answer
#
# $$
# \begin{aligned}
#     Q^\pi(s,a)= r(s,a) + \gamma \mathbb E_{p^\pi}\left[
#         \sum_{t=1} \gamma^{t-1}r(s_t,a_t) | s_1=s, a_1=a
#     \right]  \\
#     Q^\pi(s,a)= r(s,a) + \gamma \mathbb E_{(s',a')\sim p(\cdot|s,a)}\left[
#         \mathbb E_{p^\pi}\left[
#         \sum_{t=0} \gamma^{t}r(s_t,a_t) | s_0=s', a_0=a'
#         \right]
#     \right]  \\
#     Q^\pi(s,a)= r(s,a) + \gamma \mathbb E_{(s',a')\sim p(\cdot|s,a)}\left[
#         Q^\pi(s',a')
#     \right]
# \end{aligned}
# $$
# From which we find:$$
# \begin{aligned}
#     Q^*(s,a)= \max_\pi Q^\pi(s,a) = Q^{\pi^*}(s,a) \\
#     Q^*(s,a)= r(s,a) + \gamma \mathbb E_{(s',a')\sim p^{\pi^*}(s,a)}[
#         Q^{\pi^*}(s',a')
#     ]
# \end{aligned}
# $$and because $\pi^*(s) = \arg\max_a Q^*(s,a)$ for a given state $s$.
#
# Then: $$
# \begin{aligned}
#     Q^*(s,a) = r(s,a) + \gamma \mathbb E_{s'\sim p(\cdot|s,a)}
#     \left[
#         \max_{a'} Q^*(s',a')
#     \right]
# \end{aligned}
# $$
#
# Hence we can use as objective function for evaluating a policy, the Bellman error between the two terms of the equality.

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        if len(self.memory)<=self.max_memory:
            self.memory.append(m)
        else:
            # if max_memory is reached, we forget oldest action and append newest
            self.memory = self.memory[1:]
            self.memory.append(m)
        return
        

    def random_access(self):
        #return random access, and index
        a = np.random.randint(0,len(self.memory))
        return self.memory[a]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        print( 'epoch {0}/{1}'.format(e,epoch))
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0
        

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)
            

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({}) | Average score til now : {}"
              .format(e, epoch, loss, win, lose, win-lose,score/(e+1)))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size
        
        #Add a model variable
        self.model = None
        

    def learned_act(self, s):
        # learned act returns action with maximum q value
        action_values = self.model.predict(s.reshape((1,5,5,self.n_state))) #is action value a list of arrays?
        action = action_values[0].argsort()[-1] 
        return action

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4)) #4 possible actions on each state
        
        ######## FILL IN
        
        #sample minibatch
        for i in range(self.batch_size):
            access = self.memory.random_access()
            state = access[0]
            action = access[2]
            new_state = access[1]
            reward = access[3]
            game_over = access[-1]
            input_states[i] = state #dimension problem?
            if game_over == True: 
                target_q[i,action] = reward #replace action by : if doesn't work
            else:
                target_q[i,action] = reward + self.model.predict(new_state.reshape((1,5,5,self.n_state))).max()*self.discount
        ######## FILL IN
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        #on update on weight
        
        target_q = np.clip(target_q, -3, 3)
        
        
        l = self.model.train_on_batch(input_states, target_q) #returns update of the training loss of the model
            
        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        # NN Model
     
        
        model = Sequential([
            keras.layers.Flatten(input_shape=(5, 5, self.n_state)),
            Dense(32, activation='relu'),
            Dense(16, activation='relu'),
            Dense(self.n_action)  # output layer
        ])
        
        model.summary()
        
        model.compile(keras.optimizers.adam(lr=lr), "mse")
        self.model = model

# %% [markdown]
# #### BEST MODEL
#
# we find that good results are achieved with a memory size of 2000, a batch size of 32 with a learning rate of 1e-4
#
# The 'average score till now' is the sum of all scores observed so far divided by the number of elapsed epochs.
#
# The convergence is much slower here than with the CNN the network starts getting good results after 40 epochs of training. We then reach an average score over 2 on 120 epochs and which keeps improving.
#
# Our average score while training is around -0.7 whereas the random agent has an average score of -4.5.

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=0.0001, epsilon = 0.1, memory_size=2000, batch_size = 32)
epochs_train=120
train(agent, env, epochs_train, prefix='fc_train')
#HTML(display_videos('fc_train10.mp4'))
# Out:
# Model: "sequential_60"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_60 (Flatten)         (None, 50)                0
# _________________________________________________________________
# dense_230 (Dense)            (None, 32)                1632
# _________________________________________________________________
# dense_231 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_232 (Dense)            (None, 4)                 68
# =================================================================
# Total params: 2,228
# Trainable params: 2,228
# Non-trainable params: 0
# _________________________________________________________________
# epoch 0/120
# Epoch 000/120 | Loss 0.0042 | Win/lose count 1.0/2.0 (-1.0) | Average score til now : -1.0
# epoch 1/120
# Epoch 001/120 | Loss 0.0126 | Win/lose count 6.5/8.0 (-1.5) | Average score til now : -1.25
# epoch 2/120
# Epoch 002/120 | Loss 0.0056 | Win/lose count 1.0/10.0 (-9.0) | Average score til now : -3.8333333333333335
# epoch 3/120
# Epoch 003/120 | Loss 0.0149 | Win/lose count 4.0/6.0 (-2.0) | Average score til now : -3.375
# epoch 4/120
# Epoch 004/120 | Loss 0.0068 | Win/lose count 6.5/2.0 (4.5) | Average score til now : -1.8
# epoch 5/120
# Epoch 005/120 | Loss 0.0084 | Win/lose count 4.0/3.0 (1.0) | Average score til now : -1.3333333333333333
# epoch 6/120
# Epoch 006/120 | Loss 0.0049 | Win/lose count 4.5/8.0 (-3.5) | Average score til now : -1.6428571428571428
# epoch 7/120
# Epoch 007/120 | Loss 0.0084 | Win/lose count 6.5/11.0 (-4.5) | Average score til now : -2.0
# epoch 8/120
# Epoch 008/120 | Loss 0.0106 | Win/lose count 5.0/8.0 (-3.0) | Average score til now : -2.111111111111111
# epoch 9/120
# Epoch 009/120 | Loss 0.0145 | Win/lose count 6.5/5.0 (1.5) | Average score til now : -1.75
# epoch 10/120
# Epoch 010/120 | Loss 0.0031 | Win/lose count 3.5/5.0 (-1.5) | Average score til now : -1.7272727272727273
# epoch 11/120
# Epoch 011/120 | Loss 0.0163 | Win/lose count 7.0/7.0 (0.0) | Average score til now : -1.5833333333333333
# epoch 12/120
# Epoch 012/120 | Loss 0.0121 | Win/lose count 2.0/5.0 (-3.0) | Average score til now : -1.6923076923076923
# epoch 13/120
# Epoch 013/120 | Loss 0.0120 | Win/lose count 4.5/6.0 (-1.5) | Average score til now : -1.6785714285714286
# epoch 14/120
# Epoch 014/120 | Loss 0.0097 | Win/lose count 6.5/4.0 (2.5) | Average score til now : -1.4
# epoch 15/120
# Epoch 015/120 | Loss 0.0254 | Win/lose count 3.5/5.0 (-1.5) | Average score til now : -1.40625
# epoch 16/120
# Epoch 016/120 | Loss 0.0128 | Win/lose count 4.5/4.0 (0.5) | Average score til now : -1.2941176470588236
# epoch 17/120
# Epoch 017/120 | Loss 0.0125 | Win/lose count 2.5/4.0 (-1.5) | Average score til now : -1.3055555555555556
# epoch 18/120
# Epoch 018/120 | Loss 0.0061 | Win/lose count 1.0/4.0 (-3.0) | Average score til now : -1.394736842105263
# epoch 19/120
# Epoch 019/120 | Loss 0.0108 | Win/lose count 6.0/2.0 (4.0) | Average score til now : -1.125
# epoch 20/120
# Epoch 020/120 | Loss 0.0158 | Win/lose count 4.0/5.0 (-1.0) | Average score til now : -1.119047619047619
# epoch 21/120
# Epoch 021/120 | Loss 0.0058 | Win/lose count 5.5/6.0 (-0.5) | Average score til now : -1.0909090909090908
# epoch 22/120
# Epoch 022/120 | Loss 0.0098 | Win/lose count 2.5/2.0 (0.5) | Average score til now : -1.0217391304347827
# epoch 23/120
# Epoch 023/120 | Loss 0.0162 | Win/lose count 5.5/3.0 (2.5) | Average score til now : -0.875
# epoch 24/120
# Epoch 024/120 | Loss 0.0039 | Win/lose count 2.0/1.0 (1.0) | Average score til now : -0.8
# epoch 25/120
# Epoch 025/120 | Loss 0.0069 | Win/lose count 2.5/4.0 (-1.5) | Average score til now : -0.8269230769230769
# epoch 26/120
# Epoch 026/120 | Loss 0.0067 | Win/lose count 5.5/2.0 (3.5) | Average score til now : -0.6666666666666666
# epoch 27/120
# Epoch 027/120 | Loss 0.0212 | Win/lose count 6.5/8.0 (-1.5) | Average score til now : -0.6964285714285714
# epoch 28/120
# Epoch 028/120 | Loss 0.0148 | Win/lose count 3.0/2.0 (1.0) | Average score til now : -0.6379310344827587
# epoch 29/120
# Epoch 029/120 | Loss 0.0075 | Win/lose count 6.5/10.0 (-3.5) | Average score til now : -0.7333333333333333
# epoch 30/120
# Epoch 030/120 | Loss 0.0168 | Win/lose count 12.5/5.0 (7.5) | Average score til now : -0.46774193548387094
# epoch 31/120
# Epoch 031/120 | Loss 0.0043 | Win/lose count 4.0/3.0 (1.0) | Average score til now : -0.421875
# epoch 32/120
# Epoch 032/120 | Loss 0.0024 | Win/lose count 5.5/3.0 (2.5) | Average score til now : -0.3333333333333333
# epoch 33/120
# Epoch 033/120 | Loss 0.0092 | Win/lose count 4.5/7.0 (-2.5) | Average score til now : -0.39705882352941174
# epoch 34/120
# Epoch 034/120 | Loss 0.0037 | Win/lose count 8.5/6.0 (2.5) | Average score til now : -0.3142857142857143
# epoch 35/120
# Epoch 035/120 | Loss 0.0158 | Win/lose count 6.5/5.0 (1.5) | Average score til now : -0.2638888888888889
# epoch 36/120
# Epoch 036/120 | Loss 0.0118 | Win/lose count 1.5/2.0 (-0.5) | Average score til now : -0.2702702702702703
# epoch 37/120
# Epoch 037/120 | Loss 0.0028 | Win/lose count 5.5/5.0 (0.5) | Average score til now : -0.25
# epoch 38/120
# Epoch 038/120 | Loss 0.0007 | Win/lose count 5.5/3.0 (2.5) | Average score til now : -0.1794871794871795
# epoch 39/120
# Epoch 039/120 | Loss 0.0006 | Win/lose count 5.5/5.0 (0.5) | Average score til now : -0.1625
# epoch 40/120
# Epoch 040/120 | Loss 0.0035 | Win/lose count 8.5/5.0 (3.5) | Average score til now : -0.07317073170731707
# epoch 41/120
# Epoch 041/120 | Loss 0.0032 | Win/lose count 4.0/2.0 (2.0) | Average score til now : -0.023809523809523808
# epoch 42/120
# Epoch 042/120 | Loss 0.0006 | Win/lose count 3.0/5.0 (-2.0) | Average score til now : -0.06976744186046512
# epoch 43/120
# Epoch 043/120 | Loss 0.0052 | Win/lose count 9.0/7.0 (2.0) | Average score til now : -0.022727272727272728
# epoch 44/120
# Epoch 044/120 | Loss 0.0102 | Win/lose count 9.0/2.0 (7.0) | Average score til now : 0.13333333333333333
# epoch 45/120
# Epoch 045/120 | Loss 0.0083 | Win/lose count 9.0/3.0 (6.0) | Average score til now : 0.2608695652173913
# epoch 46/120
# Epoch 046/120 | Loss 0.0010 | Win/lose count 5.0/4.0 (1.0) | Average score til now : 0.2765957446808511
# epoch 47/120
# Epoch 047/120 | Loss 0.0007 | Win/lose count 1.5/2.0 (-0.5) | Average score til now : 0.2604166666666667
# epoch 48/120
# Epoch 048/120 | Loss 0.0041 | Win/lose count 5.0/5.0 (0.0) | Average score til now : 0.25510204081632654
# epoch 49/120
# Epoch 049/120 | Loss 0.0085 | Win/lose count 3.0/1.0 (2.0) | Average score til now : 0.29
# epoch 50/120
# Epoch 050/120 | Loss 0.0013 | Win/lose count 7.0/3.0 (4.0) | Average score til now : 0.3627450980392157
# epoch 51/120
# Epoch 051/120 | Loss 0.0166 | Win/lose count 4.5/3.0 (1.5) | Average score til now : 0.38461538461538464
# epoch 52/120
# Epoch 052/120 | Loss 0.0031 | Win/lose count 8.5/2.0 (6.5) | Average score til now : 0.5
# epoch 53/120
# Epoch 053/120 | Loss 0.0008 | Win/lose count 2.0/4.0 (-2.0) | Average score til now : 0.4537037037037037
# epoch 54/120
# Epoch 054/120 | Loss 0.0096 | Win/lose count 6.0/5.0 (1.0) | Average score til now : 0.4636363636363636
# epoch 55/120
# Epoch 055/120 | Loss 0.0040 | Win/lose count 6.5/8.0 (-1.5) | Average score til now : 0.42857142857142855
# epoch 56/120
# Epoch 056/120 | Loss 0.0111 | Win/lose count 2.0/10.0 (-8.0) | Average score til now : 0.2807017543859649
# epoch 57/120
# Epoch 057/120 | Loss 0.0016 | Win/lose count 1.5/2.0 (-0.5) | Average score til now : 0.2672413793103448
# epoch 58/120
# Epoch 058/120 | Loss 0.0020 | Win/lose count 5.5/4.0 (1.5) | Average score til now : 0.288135593220339
# epoch 59/120
# Epoch 059/120 | Loss 0.0117 | Win/lose count 5.0/1.0 (4.0) | Average score til now : 0.35
# epoch 60/120
# Epoch 060/120 | Loss 0.0132 | Win/lose count 6.0/7.0 (-1.0) | Average score til now : 0.32786885245901637
# epoch 61/120
# Epoch 061/120 | Loss 0.0017 | Win/lose count 7.0/6.0 (1.0) | Average score til now : 0.3387096774193548
# epoch 62/120
# Epoch 062/120 | Loss 0.0033 | Win/lose count 8.5/4.0 (4.5) | Average score til now : 0.40476190476190477
# epoch 63/120
# Epoch 063/120 | Loss 0.0213 | Win/lose count 2.0/6.0 (-4.0) | Average score til now : 0.3359375
# epoch 64/120
# Epoch 064/120 | Loss 0.0132 | Win/lose count 7.5/7.0 (0.5) | Average score til now : 0.3384615384615385
# epoch 65/120
# Epoch 065/120 | Loss 0.0161 | Win/lose count 7.0/3.0 (4.0) | Average score til now : 0.3939393939393939
# epoch 66/120
# Epoch 066/120 | Loss 0.0056 | Win/lose count 5.5/2.0 (3.5) | Average score til now : 0.44029850746268656
# epoch 67/120
# Epoch 067/120 | Loss 0.0138 | Win/lose count 10.0/4.0 (6.0) | Average score til now : 0.5220588235294118
# epoch 68/120
# Epoch 068/120 | Loss 0.0215 | Win/lose count 6.5/5.0 (1.5) | Average score til now : 0.5362318840579711
# epoch 69/120
# Epoch 069/120 | Loss 0.0167 | Win/lose count 7.5/7.0 (0.5) | Average score til now : 0.5357142857142857
# epoch 70/120
# Epoch 070/120 | Loss 0.0120 | Win/lose count 7.5/2.0 (5.5) | Average score til now : 0.6056338028169014
# epoch 71/120
# Epoch 071/120 | Loss 0.0103 | Win/lose count 9.0/6.0 (3.0) | Average score til now : 0.6388888888888888
# epoch 72/120
# Epoch 072/120 | Loss 0.0095 | Win/lose count 8.5/1.0 (7.5) | Average score til now : 0.7328767123287672
# epoch 73/120
# Epoch 073/120 | Loss 0.0023 | Win/lose count 4.5/4.0 (0.5) | Average score til now : 0.7297297297297297
# epoch 74/120
# Epoch 074/120 | Loss 0.0065 | Win/lose count 1.0/0 (1.0) | Average score til now : 0.7333333333333333
# epoch 75/120
# Epoch 075/120 | Loss 0.0023 | Win/lose count 8.5/8.0 (0.5) | Average score til now : 0.7302631578947368
# epoch 76/120
# Epoch 076/120 | Loss 0.0018 | Win/lose count 7.5/4.0 (3.5) | Average score til now : 0.7662337662337663
# epoch 77/120
# Epoch 077/120 | Loss 0.0196 | Win/lose count 5.0/2.0 (3.0) | Average score til now : 0.7948717948717948
# epoch 78/120
# Epoch 078/120 | Loss 0.0208 | Win/lose count 5.5/5.0 (0.5) | Average score til now : 0.7911392405063291
# epoch 79/120
# Epoch 079/120 | Loss 0.0211 | Win/lose count 3.0/5.0 (-2.0) | Average score til now : 0.75625
# epoch 80/120
# Epoch 080/120 | Loss 0.0032 | Win/lose count 9.5/4.0 (5.5) | Average score til now : 0.8148148148148148
# epoch 81/120
# Epoch 081/120 | Loss 0.0011 | Win/lose count 7.5/0 (7.5) | Average score til now : 0.8963414634146342
# epoch 82/120
# Epoch 082/120 | Loss 0.0115 | Win/lose count 7.0/4.0 (3.0) | Average score til now : 0.9216867469879518
# epoch 83/120
# Epoch 083/120 | Loss 0.0099 | Win/lose count 7.0/7.0 (0.0) | Average score til now : 0.9107142857142857
# epoch 84/120
# Epoch 084/120 | Loss 0.0045 | Win/lose count 4.0/1.0 (3.0) | Average score til now : 0.9352941176470588
# epoch 85/120
# Epoch 085/120 | Loss 0.0105 | Win/lose count 6.5/2.0 (4.5) | Average score til now : 0.9767441860465116
# epoch 86/120
# Epoch 086/120 | Loss 0.0159 | Win/lose count 11.5/5.0 (6.5) | Average score til now : 1.0402298850574712
# epoch 87/120
# Epoch 087/120 | Loss 0.0066 | Win/lose count 8.0/6.0 (2.0) | Average score til now : 1.0511363636363635
# epoch 88/120
# Epoch 088/120 | Loss 0.0024 | Win/lose count 3.0/4.0 (-1.0) | Average score til now : 1.0280898876404494
# epoch 89/120
# Epoch 089/120 | Loss 0.0162 | Win/lose count 6.0/0 (6.0) | Average score til now : 1.0833333333333333
# epoch 90/120
# Epoch 090/120 | Loss 0.0048 | Win/lose count 8.0/4.0 (4.0) | Average score til now : 1.1153846153846154
# epoch 91/120
# Epoch 091/120 | Loss 0.0038 | Win/lose count 7.0/5.0 (2.0) | Average score til now : 1.125
# epoch 92/120
# Epoch 092/120 | Loss 0.0111 | Win/lose count 11.0/3.0 (8.0) | Average score til now : 1.1989247311827957
# epoch 93/120
# Epoch 093/120 | Loss 0.0031 | Win/lose count 9.5/1.0 (8.5) | Average score til now : 1.2765957446808511
# epoch 94/120
# Epoch 094/120 | Loss 0.0115 | Win/lose count 5.0/6.0 (-1.0) | Average score til now : 1.2526315789473683
# epoch 95/120
# Epoch 095/120 | Loss 0.0206 | Win/lose count 9.5/8.0 (1.5) | Average score til now : 1.2552083333333333
# epoch 96/120
# Epoch 096/120 | Loss 0.0023 | Win/lose count 5.5/1.0 (4.5) | Average score til now : 1.288659793814433
# epoch 97/120
# Epoch 097/120 | Loss 0.0132 | Win/lose count 5.5/3.0 (2.5) | Average score til now : 1.3010204081632653
# epoch 98/120
# Epoch 098/120 | Loss 0.0116 | Win/lose count 9.5/2.0 (7.5) | Average score til now : 1.3636363636363635
# epoch 99/120
# Epoch 099/120 | Loss 0.0145 | Win/lose count 5.5/3.0 (2.5) | Average score til now : 1.375
# epoch 100/120
# Epoch 100/120 | Loss 0.0039 | Win/lose count 19.0/4.0 (15.0) | Average score til now : 1.50990099009901
# epoch 101/120
# Epoch 101/120 | Loss 0.0117 | Win/lose count 10.0/6.0 (4.0) | Average score til now : 1.5343137254901962
# epoch 102/120
# Epoch 102/120 | Loss 0.0067 | Win/lose count 8.0/5.0 (3.0) | Average score til now : 1.5485436893203883
# epoch 103/120
# Epoch 103/120 | Loss 0.0158 | Win/lose count 11.5/2.0 (9.5) | Average score til now : 1.625
# epoch 104/120
# Epoch 104/120 | Loss 0.0074 | Win/lose count 14.0/3.0 (11.0) | Average score til now : 1.7142857142857142
# epoch 105/120
# Epoch 105/120 | Loss 0.0052 | Win/lose count 12.0/4.0 (8.0) | Average score til now : 1.7735849056603774
# epoch 106/120
# Epoch 106/120 | Loss 0.0063 | Win/lose count 7.5/1.0 (6.5) | Average score til now : 1.8177570093457944
# epoch 107/120
# Epoch 107/120 | Loss 0.0037 | Win/lose count 1.5/3.0 (-1.5) | Average score til now : 1.787037037037037
# epoch 108/120
# Epoch 108/120 | Loss 0.0047 | Win/lose count 9.5/2.0 (7.5) | Average score til now : 1.8394495412844036
# epoch 109/120
# Epoch 109/120 | Loss 0.0222 | Win/lose count 14.5/6.0 (8.5) | Average score til now : 1.9
# epoch 110/120
# Epoch 110/120 | Loss 0.0182 | Win/lose count 9.0/4.0 (5.0) | Average score til now : 1.927927927927928
# epoch 111/120
# Epoch 111/120 | Loss 0.0183 | Win/lose count 11.5/4.0 (7.5) | Average score til now : 1.9776785714285714
# epoch 112/120
# Epoch 112/120 | Loss 0.0159 | Win/lose count 11.0/11.0 (0.0) | Average score til now : 1.9601769911504425
# epoch 113/120
# Epoch 113/120 | Loss 0.0038 | Win/lose count 15.5/5.0 (10.5) | Average score til now : 2.0350877192982457
# epoch 114/120
# Epoch 114/120 | Loss 0.0158 | Win/lose count 15.5/4.0 (11.5) | Average score til now : 2.117391304347826
# epoch 115/120
# Epoch 115/120 | Loss 0.0153 | Win/lose count 5.0/2.0 (3.0) | Average score til now : 2.125
# epoch 116/120
# Epoch 116/120 | Loss 0.0115 | Win/lose count 12.0/5.0 (7.0) | Average score til now : 2.1666666666666665
# epoch 117/120
# Epoch 117/120 | Loss 0.0109 | Win/lose count 16.0/3.0 (13.0) | Average score til now : 2.2584745762711864
# epoch 118/120
# Epoch 118/120 | Loss 0.0326 | Win/lose count 13.5/4.0 (9.5) | Average score til now : 2.319327731092437
# epoch 119/120
# Epoch 119/120 | Loss 0.0187 | Win/lose count 13.5/6.0 (7.5) | Average score til now : 2.3625

# %%
display2('fc_train99.mp4')

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        ###### FILL IN
    
        model = Sequential([
            Conv2D(32, 3, input_shape=(5, 5, self.n_state), activation='relu', padding="same"),
            Conv2D(64, 3, activation='relu', padding="same"),
            Conv2D(32, 3, activation='relu', padding="same"),
            keras.layers.Flatten(),
            Dense(self.n_action)  # output
        ])
        
        model.summary()
        
        model.compile(keras.optimizers.adam(lr=lr), "mse")
        self.model = model

# %% [markdown]
# #### Answer
# Likewise we achieve satisfactory results with the following configuration ie: lr=.00001, epsilon = 0.1, memory_size=2000, batch_size = 32
#
# The average score seems to be slightly higher around 3.5 after a few training epochs. The convergence seems to happen quite quickly.

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.00001, epsilon = 0.1, memory_size=2000, batch_size = 32)
epochs_train = 85
train(agent,env,epochs_train,prefix='cnn_train')
#HTML(display_videos('cnn_train10.mp4'))
# Out:
# Model: "sequential_58"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_58 (Conv2D)           (None, 5, 5, 32)          608
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 5, 5, 64)          18496
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 5, 5, 32)          18464
# _________________________________________________________________
# flatten_58 (Flatten)         (None, 800)               0
# _________________________________________________________________
# dense_226 (Dense)            (None, 4)                 3204
# =================================================================
# Total params: 40,772
# Trainable params: 40,772
# Non-trainable params: 0
# _________________________________________________________________
# epoch 0/85
# Epoch 000/085 | Loss 0.0114 | Win/lose count 3.5/2.0 (1.5) | Average score til now : 1.5
# epoch 1/85
# Epoch 001/085 | Loss 0.0037 | Win/lose count 1.5/6.0 (-4.5) | Average score til now : -1.5
# epoch 2/85
# Epoch 002/085 | Loss 0.0181 | Win/lose count 3.0/3.0 (0.0) | Average score til now : -1.0
# epoch 3/85
# Epoch 003/085 | Loss 0.0020 | Win/lose count 4.0/7.0 (-3.0) | Average score til now : -1.5
# epoch 4/85
# Epoch 004/085 | Loss 0.0003 | Win/lose count 8.5/4.0 (4.5) | Average score til now : -0.3
# epoch 5/85
# Epoch 005/085 | Loss 0.0138 | Win/lose count 5.5/3.0 (2.5) | Average score til now : 0.16666666666666666
# epoch 6/85
# Epoch 006/085 | Loss 0.0039 | Win/lose count 5.0/2.0 (3.0) | Average score til now : 0.5714285714285714
# epoch 7/85
# Epoch 007/085 | Loss 0.0004 | Win/lose count 9.0/3.0 (6.0) | Average score til now : 1.25
# epoch 8/85
# Epoch 008/085 | Loss 0.0024 | Win/lose count 4.0/5.0 (-1.0) | Average score til now : 1.0
# epoch 9/85
# Epoch 009/085 | Loss 0.0067 | Win/lose count 1.5/0 (1.5) | Average score til now : 1.05
# epoch 10/85
# Epoch 010/085 | Loss 0.0056 | Win/lose count 9.5/2.0 (7.5) | Average score til now : 1.6363636363636365
# epoch 11/85
# Epoch 011/085 | Loss 0.0023 | Win/lose count 7.0/7.0 (0.0) | Average score til now : 1.5
# epoch 12/85
# Epoch 012/085 | Loss 0.0005 | Win/lose count 4.5/2.0 (2.5) | Average score til now : 1.5769230769230769
# epoch 13/85
# Epoch 013/085 | Loss 0.0108 | Win/lose count 8.0/3.0 (5.0) | Average score til now : 1.8214285714285714
# epoch 14/85
# Epoch 014/085 | Loss 0.0070 | Win/lose count 3.5/6.0 (-2.5) | Average score til now : 1.5333333333333334
# epoch 15/85
# Epoch 015/085 | Loss 0.0087 | Win/lose count 7.0/2.0 (5.0) | Average score til now : 1.75
# epoch 16/85
# Epoch 016/085 | Loss 0.0060 | Win/lose count 2.5/1.0 (1.5) | Average score til now : 1.7352941176470589
# epoch 17/85
# Epoch 017/085 | Loss 0.0025 | Win/lose count 5.5/0 (5.5) | Average score til now : 1.9444444444444444
# epoch 18/85
# Epoch 018/085 | Loss 0.0057 | Win/lose count 8.0/1.0 (7.0) | Average score til now : 2.210526315789474
# epoch 19/85
# Epoch 019/085 | Loss 0.0063 | Win/lose count 6.0/3.0 (3.0) | Average score til now : 2.25
# epoch 20/85
# Epoch 020/085 | Loss 0.0025 | Win/lose count 2.0/1.0 (1.0) | Average score til now : 2.1904761904761907
# epoch 21/85
# Epoch 021/085 | Loss 0.0060 | Win/lose count 3.0/2.0 (1.0) | Average score til now : 2.1363636363636362
# epoch 22/85
# Epoch 022/085 | Loss 0.0035 | Win/lose count 5.0/4.0 (1.0) | Average score til now : 2.0869565217391304
# epoch 23/85
# Epoch 023/085 | Loss 0.0020 | Win/lose count 9.0/2.0 (7.0) | Average score til now : 2.2916666666666665
# epoch 24/85
# Epoch 024/085 | Loss 0.0036 | Win/lose count 7.5/6.0 (1.5) | Average score til now : 2.26
# epoch 25/85
# Epoch 025/085 | Loss 0.0067 | Win/lose count 4.5/1.0 (3.5) | Average score til now : 2.3076923076923075
# epoch 26/85
# Epoch 026/085 | Loss 0.0079 | Win/lose count 10.5/4.0 (6.5) | Average score til now : 2.462962962962963
# epoch 27/85
# Epoch 027/085 | Loss 0.0172 | Win/lose count 7.0/2.0 (5.0) | Average score til now : 2.5535714285714284
# epoch 28/85
# Epoch 028/085 | Loss 0.0006 | Win/lose count 10.0/7.0 (3.0) | Average score til now : 2.5689655172413794
# epoch 29/85
# Epoch 029/085 | Loss 0.0066 | Win/lose count 3.5/2.0 (1.5) | Average score til now : 2.533333333333333
# epoch 30/85
# Epoch 030/085 | Loss 0.0044 | Win/lose count 8.5/5.0 (3.5) | Average score til now : 2.564516129032258
# epoch 31/85
# Epoch 031/085 | Loss 0.0036 | Win/lose count 9.5/0 (9.5) | Average score til now : 2.78125
# epoch 32/85
# Epoch 032/085 | Loss 0.0028 | Win/lose count 6.5/2.0 (4.5) | Average score til now : 2.8333333333333335
# epoch 33/85
# Epoch 033/085 | Loss 0.0032 | Win/lose count 10.0/3.0 (7.0) | Average score til now : 2.9558823529411766
# epoch 34/85
# Epoch 034/085 | Loss 0.0051 | Win/lose count 6.5/5.0 (1.5) | Average score til now : 2.914285714285714
# epoch 35/85
# Epoch 035/085 | Loss 0.0086 | Win/lose count 8.0/9.0 (-1.0) | Average score til now : 2.8055555555555554
# epoch 36/85
# Epoch 036/085 | Loss 0.0091 | Win/lose count 14.5/10.0 (4.5) | Average score til now : 2.8513513513513513
# epoch 37/85
# Epoch 037/085 | Loss 0.0057 | Win/lose count 7.0/1.0 (6.0) | Average score til now : 2.9342105263157894
# epoch 38/85
# Epoch 038/085 | Loss 0.0068 | Win/lose count 1.5/2.0 (-0.5) | Average score til now : 2.8461538461538463
# epoch 39/85
# Epoch 039/085 | Loss 0.0126 | Win/lose count 9.5/2.0 (7.5) | Average score til now : 2.9625
# epoch 40/85
# Epoch 040/085 | Loss 0.0138 | Win/lose count 5.0/1.0 (4.0) | Average score til now : 2.9878048780487805
# epoch 41/85
# Epoch 041/085 | Loss 0.0077 | Win/lose count 8.0/6.0 (2.0) | Average score til now : 2.9642857142857144
# epoch 42/85
# Epoch 042/085 | Loss 0.0045 | Win/lose count 8.0/6.0 (2.0) | Average score til now : 2.941860465116279
# epoch 43/85
# Epoch 043/085 | Loss 0.0033 | Win/lose count 7.0/4.0 (3.0) | Average score til now : 2.9431818181818183
# epoch 44/85
# Epoch 044/085 | Loss 0.0164 | Win/lose count 9.0/3.0 (6.0) | Average score til now : 3.011111111111111
# epoch 45/85
# Epoch 045/085 | Loss 0.0072 | Win/lose count 8.0/1.0 (7.0) | Average score til now : 3.097826086956522
# epoch 46/85
# Epoch 046/085 | Loss 0.0109 | Win/lose count 9.5/5.0 (4.5) | Average score til now : 3.127659574468085
# epoch 47/85
# Epoch 047/085 | Loss 0.0099 | Win/lose count 10.0/4.0 (6.0) | Average score til now : 3.1875
# epoch 48/85
# Epoch 048/085 | Loss 0.0175 | Win/lose count 4.0/2.0 (2.0) | Average score til now : 3.163265306122449
# epoch 49/85
# Epoch 049/085 | Loss 0.0091 | Win/lose count 12.5/3.0 (9.5) | Average score til now : 3.29
# epoch 50/85
# Epoch 050/085 | Loss 0.0179 | Win/lose count 6.0/1.0 (5.0) | Average score til now : 3.323529411764706
# epoch 51/85
# Epoch 051/085 | Loss 0.0026 | Win/lose count 3.5/0 (3.5) | Average score til now : 3.326923076923077
# epoch 52/85
# Epoch 052/085 | Loss 0.0154 | Win/lose count 9.5/1.0 (8.5) | Average score til now : 3.4245283018867925
# epoch 53/85
# Epoch 053/085 | Loss 0.0099 | Win/lose count 10.0/1.0 (9.0) | Average score til now : 3.5277777777777777
# epoch 54/85
# Epoch 054/085 | Loss 0.0089 | Win/lose count 8.0/3.0 (5.0) | Average score til now : 3.5545454545454547
# epoch 55/85
# Epoch 055/085 | Loss 0.0052 | Win/lose count 13.0/2.0 (11.0) | Average score til now : 3.6875
# epoch 56/85
# Epoch 056/085 | Loss 0.0197 | Win/lose count 8.5/0 (8.5) | Average score til now : 3.7719298245614037
# epoch 57/85
# Epoch 057/085 | Loss 0.0123 | Win/lose count 8.5/3.0 (5.5) | Average score til now : 3.8017241379310347
# epoch 58/85
# Epoch 058/085 | Loss 0.0111 | Win/lose count 7.0/2.0 (5.0) | Average score til now : 3.8220338983050848
# epoch 59/85
# Epoch 059/085 | Loss 0.0061 | Win/lose count 3.0/3.0 (0.0) | Average score til now : 3.7583333333333333
# epoch 60/85
# Epoch 060/085 | Loss 0.0148 | Win/lose count 13.0/6.0 (7.0) | Average score til now : 3.8114754098360657
# epoch 61/85
# Epoch 061/085 | Loss 0.0085 | Win/lose count 12.0/4.0 (8.0) | Average score til now : 3.879032258064516
# epoch 62/85
# Epoch 062/085 | Loss 0.0028 | Win/lose count 12.0/2.0 (10.0) | Average score til now : 3.9761904761904763
# epoch 63/85
# Epoch 063/085 | Loss 0.0138 | Win/lose count 9.0/3.0 (6.0) | Average score til now : 4.0078125
# epoch 64/85
# Epoch 064/085 | Loss 0.0125 | Win/lose count 11.5/5.0 (6.5) | Average score til now : 4.046153846153846
# epoch 65/85
# Epoch 065/085 | Loss 0.0098 | Win/lose count 7.0/7.0 (0.0) | Average score til now : 3.984848484848485
# epoch 66/85
# Epoch 066/085 | Loss 0.0197 | Win/lose count 4.5/3.0 (1.5) | Average score til now : 3.9477611940298507
# epoch 67/85
# Epoch 067/085 | Loss 0.0124 | Win/lose count 7.0/5.0 (2.0) | Average score til now : 3.9191176470588234
# epoch 68/85
# Epoch 068/085 | Loss 0.0122 | Win/lose count 5.5/1.0 (4.5) | Average score til now : 3.927536231884058
# epoch 69/85
# Epoch 069/085 | Loss 0.0082 | Win/lose count 9.0/3.0 (6.0) | Average score til now : 3.9571428571428573
# epoch 70/85
# Epoch 070/085 | Loss 0.0125 | Win/lose count 3.5/4.0 (-0.5) | Average score til now : 3.8943661971830985
# epoch 71/85
# Epoch 071/085 | Loss 0.0123 | Win/lose count 1.0/2.0 (-1.0) | Average score til now : 3.826388888888889
# epoch 72/85
# Epoch 072/085 | Loss 0.0090 | Win/lose count 9.5/4.0 (5.5) | Average score til now : 3.8493150684931505
# epoch 73/85
# Epoch 073/085 | Loss 0.0108 | Win/lose count 8.5/7.0 (1.5) | Average score til now : 3.8175675675675675
# epoch 74/85
# Epoch 074/085 | Loss 0.0127 | Win/lose count 9.0/2.0 (7.0) | Average score til now : 3.86
# epoch 75/85
# Epoch 075/085 | Loss 0.0145 | Win/lose count 8.0/3.0 (5.0) | Average score til now : 3.875
# epoch 76/85
# Epoch 076/085 | Loss 0.0084 | Win/lose count 10.5/3.0 (7.5) | Average score til now : 3.9220779220779223
# epoch 77/85
# Epoch 077/085 | Loss 0.0047 | Win/lose count 8.0/6.0 (2.0) | Average score til now : 3.8974358974358974
# epoch 78/85
# Epoch 078/085 | Loss 0.0119 | Win/lose count 5.5/3.0 (2.5) | Average score til now : 3.8797468354430378
# epoch 79/85
# Epoch 079/085 | Loss 0.0190 | Win/lose count 7.5/5.0 (2.5) | Average score til now : 3.8625
# epoch 80/85
# Epoch 080/085 | Loss 0.0046 | Win/lose count 9.0/2.0 (7.0) | Average score til now : 3.9012345679012346
# epoch 81/85
# Epoch 081/085 | Loss 0.0034 | Win/lose count 10.0/2.0 (8.0) | Average score til now : 3.951219512195122
# epoch 82/85
# Epoch 082/085 | Loss 0.0089 | Win/lose count 10.5/3.0 (7.5) | Average score til now : 3.9939759036144578
# epoch 83/85
# Epoch 083/085 | Loss 0.0045 | Win/lose count 10.5/2.0 (8.5) | Average score til now : 4.0476190476190474
# epoch 84/85
# Epoch 084/085 | Loss 0.0047 | Win/lose count 4.0/8.0 (-4.0) | Average score til now : 3.9529411764705884

# %%
display2('cnn_train20.mp4')

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %% [markdown]
# We load both models trained for T=0.3. We see that the performances of the CNN are a lot better with average score much greater than  that of the fully connected network.
#
# However the display of the trajectories show that the agent tends to stay on only one side of the board, especially for low temperatures.
#
#
# This results in sub-optimal performance for certain temperatures. For instance with  T=0.8 there are many rewards to collect and we should expect a really high score (>15 with the random model) but we only see a score of 4.
#
# For T=0.1 the performance is on par with T=0.3.
#
# The CNN seems to be quite good at avoiding losses but this is in part due to a low exploration of the board, this also leads to a lower average number of wins than the random explorer albeit with a better overall score, for high temperatures like T=0.8.
#
# The FC is suboptimal for high temperatures like 0.8 with an average score around 9 whereas the random explorer achieves a score of 15. This is due to low exploration in an environment where there are many rewards to reap.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=1e-5, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=1e-4, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
epochs_test = 50
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Model: "sequential_61"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_61 (Conv2D)           (None, 5, 5, 32)          608
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 5, 5, 64)          18496
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 5, 5, 32)          18464
# _________________________________________________________________
# flatten_61 (Flatten)         (None, 800)               0
# _________________________________________________________________
# dense_233 (Dense)            (None, 4)                 3204
# =================================================================
# Total params: 40,772
# Trainable params: 40,772
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_62 (Flatten)         (None, 50)                0
# _________________________________________________________________
# dense_234 (Dense)            (None, 32)                1632
# _________________________________________________________________
# dense_235 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_236 (Dense)            (None, 4)                 68
# =================================================================
# Total params: 2,228
# Trainable params: 2,228
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 19.5/6.0. Average score (13.5)
# Win/lose count 7.0/3.0. Average score (8.75)
# Win/lose count 7.5/3.0. Average score (7.333333333333333)
# Win/lose count 11.5/5.0. Average score (7.125)
# Win/lose count 9.0/5.0. Average score (6.5)
# Win/lose count 10.5/3.0. Average score (6.666666666666667)
# Win/lose count 9.5/6.0. Average score (6.214285714285714)
# Win/lose count 18.5/14.0. Average score (6.0)
# Win/lose count 7.5/3.0. Average score (5.833333333333333)
# Win/lose count 9.5/6.0. Average score (5.6)
# Win/lose count 5.5/5.0. Average score (5.136363636363637)
# Win/lose count 7.0/2.0. Average score (5.125)
# Win/lose count 16.0/2.0. Average score (5.8076923076923075)
# Win/lose count 6.0/1.0. Average score (5.75)
# Win/lose count 10.5/4.0. Average score (5.8)
# Win/lose count 8.5/7.0. Average score (5.53125)
# Win/lose count 9.5/5.0. Average score (5.470588235294118)
# Win/lose count 11.0/3.0. Average score (5.611111111111111)
# Win/lose count 8.5/3.0. Average score (5.605263157894737)
# Win/lose count 8.0/4.0. Average score (5.525)
# Win/lose count 13.0/6.0. Average score (5.595238095238095)
# Win/lose count 11.0/10.0. Average score (5.386363636363637)
# Win/lose count 8.0/3.0. Average score (5.369565217391305)
# Win/lose count 10.5/0. Average score (5.583333333333333)
# Win/lose count 12.0/6.0. Average score (5.6)
# Win/lose count 19.0/4.0. Average score (5.961538461538462)
# Win/lose count 5.5/3.0. Average score (5.833333333333333)
# Win/lose count 8.0/5.0. Average score (5.732142857142857)
# Win/lose count 6.0/1.0. Average score (5.706896551724138)
# Win/lose count 9.5/5.0. Average score (5.666666666666667)
# Win/lose count 6.5/3.0. Average score (5.596774193548387)
# Win/lose count 5.5/6.0. Average score (5.40625)
# Win/lose count 15.5/8.0. Average score (5.46969696969697)
# Win/lose count 15.0/2.0. Average score (5.6911764705882355)
# Win/lose count 5.0/2.0. Average score (5.614285714285714)
# Win/lose count 7.5/7.0. Average score (5.472222222222222)
# Win/lose count 10.0/8.0. Average score (5.378378378378378)
# Win/lose count 12.5/6.0. Average score (5.407894736842105)
# Win/lose count 11.0/7.0. Average score (5.371794871794871)
# Win/lose count 10.5/3.0. Average score (5.425)
# Win/lose count 11.5/3.0. Average score (5.5)
# Win/lose count 8.0/7.0. Average score (5.392857142857143)
# Win/lose count 12.5/8.0. Average score (5.372093023255814)
# Win/lose count 14.0/3.0. Average score (5.5)
# Win/lose count 15.0/2.0. Average score (5.666666666666667)
# Win/lose count 8.0/0. Average score (5.717391304347826)
# Win/lose count 10.5/6.0. Average score (5.691489361702128)
# Win/lose count 10.0/5.0. Average score (5.677083333333333)
# Win/lose count 16.5/8.0. Average score (5.73469387755102)
# Win/lose count 14.0/2.0. Average score (5.86)
# Final score: 5.86
# Test of the FC
# Win/lose count 2.5/3.0. Average score (-0.5)
# Win/lose count 6.5/5.0. Average score (0.5)
# Win/lose count 7.5/7.0. Average score (0.5)
# Win/lose count 6.0/6.0. Average score (0.375)
# Win/lose count 5.5/11.0. Average score (-0.8)
# Win/lose count 6.0/16.0. Average score (-2.3333333333333335)
# Win/lose count 3.0/3.0. Average score (-2.0)
# Win/lose count 8.0/9.0. Average score (-1.875)
# Win/lose count 6.0/3.0. Average score (-1.3333333333333333)
# Win/lose count 2.5/5.0. Average score (-1.45)
# Win/lose count 4.0/6.0. Average score (-1.5)
# Win/lose count 7.0/4.0. Average score (-1.125)
# Win/lose count 4.0/1.0. Average score (-0.8076923076923077)
# Win/lose count 5.5/1.0. Average score (-0.42857142857142855)
# Win/lose count 2.0/4.0. Average score (-0.5333333333333333)
# Win/lose count 5.5/6.0. Average score (-0.53125)
# Win/lose count 12.0/14.0. Average score (-0.6176470588235294)
# Win/lose count 5.0/3.0. Average score (-0.4722222222222222)
# Win/lose count 11.5/5.0. Average score (-0.10526315789473684)
# Win/lose count 8.0/6.0. Average score (0.0)
# Win/lose count 8.0/19.0. Average score (-0.5238095238095238)
# Win/lose count 8.5/9.0. Average score (-0.5227272727272727)
# Win/lose count 3.5/3.0. Average score (-0.4782608695652174)
# Win/lose count 6.0/4.0. Average score (-0.375)
# Win/lose count 3.0/2.0. Average score (-0.32)
# Win/lose count 4.0/6.0. Average score (-0.38461538461538464)
# Win/lose count 7.0/7.0. Average score (-0.37037037037037035)
# Win/lose count 8.5/10.0. Average score (-0.4107142857142857)
# Win/lose count 2.0/2.0. Average score (-0.39655172413793105)
# Win/lose count 7.0/6.0. Average score (-0.35)
# Win/lose count 5.0/6.0. Average score (-0.3709677419354839)
# Win/lose count 5.5/3.0. Average score (-0.28125)
# Win/lose count 5.5/5.0. Average score (-0.25757575757575757)
# Win/lose count 6.5/9.0. Average score (-0.3235294117647059)
# Win/lose count 2.5/6.0. Average score (-0.4142857142857143)
# Win/lose count 8.0/9.0. Average score (-0.4305555555555556)
# Win/lose count 7.0/6.0. Average score (-0.3918918918918919)
# Win/lose count 5.0/8.0. Average score (-0.4605263157894737)
# Win/lose count 3.0/5.0. Average score (-0.5)
# Win/lose count 7.5/2.0. Average score (-0.35)
# Win/lose count 5.0/9.0. Average score (-0.43902439024390244)
# Win/lose count 2.0/2.0. Average score (-0.42857142857142855)
# Win/lose count 12.0/8.0. Average score (-0.32558139534883723)
# Win/lose count 2.5/10.0. Average score (-0.48863636363636365)
# Win/lose count 8.0/8.0. Average score (-0.4777777777777778)
# Win/lose count 7.5/9.0. Average score (-0.5)
# Win/lose count 7.5/10.0. Average score (-0.5425531914893617)
# Win/lose count 5.0/5.0. Average score (-0.53125)
# Win/lose count 4.5/8.0. Average score (-0.5918367346938775)
# Win/lose count 4.5/4.0. Average score (-0.57)
# Final score: -0.57

# %%
epochs_test = 50
env = Environment(grid_size=size, max_time=T,temperature=0.1)
print('Test of the CNN with Temperature 0.1')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC with Temperature 0.1')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN with Temperature 0.1
# Win/lose count 6.0/3.0. Average score (3.0)
# Win/lose count 5.5/1.0. Average score (3.75)
# Win/lose count 7.5/3.0. Average score (4.0)
# Win/lose count 4.0/1.0. Average score (3.75)
# Win/lose count 3.0/0. Average score (3.6)
# Win/lose count 5.5/7.0. Average score (2.75)
# Win/lose count 6.0/0. Average score (3.2142857142857144)
# Win/lose count 2.0/1.0. Average score (2.9375)
# Win/lose count 5.0/3.0. Average score (2.8333333333333335)
# Win/lose count 4.0/2.0. Average score (2.75)
# Win/lose count 10.5/5.0. Average score (3.0)
# Win/lose count 3.0/1.0. Average score (2.9166666666666665)
# Win/lose count 3.5/4.0. Average score (2.6538461538461537)
# Win/lose count 10.0/1.0. Average score (3.107142857142857)
# Win/lose count 4.0/0. Average score (3.1666666666666665)
# Win/lose count 7.5/6.0. Average score (3.0625)
# Win/lose count 6.5/9.0. Average score (2.735294117647059)
# Win/lose count 4.0/2.0. Average score (2.6944444444444446)
# Win/lose count 2.0/4.0. Average score (2.4473684210526314)
# Win/lose count 5.0/3.0. Average score (2.425)
# Win/lose count 4.5/1.0. Average score (2.4761904761904763)
# Win/lose count 3.5/0. Average score (2.522727272727273)
# Win/lose count 4.0/3.0. Average score (2.4565217391304346)
# Win/lose count 6.5/1.0. Average score (2.5833333333333335)
# Win/lose count 1.5/2.0. Average score (2.46)
# Win/lose count 1.5/0. Average score (2.423076923076923)
# Win/lose count 5.5/1.0. Average score (2.5)
# Win/lose count 2.0/2.0. Average score (2.4107142857142856)
# Win/lose count 3.5/2.0. Average score (2.3793103448275863)
# Win/lose count 3.5/0. Average score (2.4166666666666665)
# Win/lose count 4.5/0. Average score (2.4838709677419355)
# Win/lose count 6.0/2.0. Average score (2.53125)
# Win/lose count 5.0/4.0. Average score (2.484848484848485)
# Win/lose count 1.5/0. Average score (2.4558823529411766)
# Win/lose count 6.5/1.0. Average score (2.5428571428571427)
# Win/lose count 3.5/0. Average score (2.5694444444444446)
# Win/lose count 2.5/2.0. Average score (2.5135135135135136)
# Win/lose count 2.0/0. Average score (2.5)
# Win/lose count 5.5/3.0. Average score (2.5)
# Win/lose count 7.5/1.0. Average score (2.6)
# Win/lose count 3.5/4.0. Average score (2.524390243902439)
# Win/lose count 6.5/4.0. Average score (2.5238095238095237)
# Win/lose count 3.0/2.0. Average score (2.488372093023256)
# Win/lose count 4.5/3.0. Average score (2.465909090909091)
# Win/lose count 4.5/1.0. Average score (2.488888888888889)
# Win/lose count 2.5/0. Average score (2.489130434782609)
# Win/lose count 2.5/4.0. Average score (2.404255319148936)
# Win/lose count 3.5/0. Average score (2.4270833333333335)
# Win/lose count 3.0/1.0. Average score (2.4183673469387754)
# Win/lose count 1.5/0. Average score (2.4)
# Final score: 2.4
# Test of the FC with Temperature 0.1
# Win/lose count 3.0/2.0. Average score (1.0)
# Win/lose count 2.0/3.0. Average score (0.0)
# Win/lose count 3.0/3.0. Average score (0.0)
# Win/lose count 1.0/2.0. Average score (-0.25)
# Win/lose count 4.0/0. Average score (0.6)
# Win/lose count 3.5/4.0. Average score (0.4166666666666667)
# Win/lose count 3.5/5.0. Average score (0.14285714285714285)
# Win/lose count 5.5/3.0. Average score (0.4375)
# Win/lose count 1.5/0. Average score (0.5555555555555556)
# Win/lose count 3.0/5.0. Average score (0.3)
# Win/lose count 1.0/0. Average score (0.36363636363636365)
# Win/lose count 1.0/1.0. Average score (0.3333333333333333)
# Win/lose count 1.5/4.0. Average score (0.11538461538461539)
# Win/lose count 2.5/4.0. Average score (0.0)
# Win/lose count 5.0/5.0. Average score (0.0)
# Win/lose count 1.5/3.0. Average score (-0.09375)
# Win/lose count 2.5/4.0. Average score (-0.17647058823529413)
# Win/lose count 2.0/3.0. Average score (-0.2222222222222222)
# Win/lose count 4.0/6.0. Average score (-0.3157894736842105)
# Win/lose count 4.5/4.0. Average score (-0.275)
# Win/lose count 1.0/2.0. Average score (-0.30952380952380953)
# Win/lose count 6.0/6.0. Average score (-0.29545454545454547)
# Win/lose count 2.0/3.0. Average score (-0.32608695652173914)
# Win/lose count 2.5/4.0. Average score (-0.375)
# Win/lose count 2.0/5.0. Average score (-0.48)
# Win/lose count 1.0/3.0. Average score (-0.5384615384615384)
# Win/lose count 4.0/7.0. Average score (-0.6296296296296297)
# Win/lose count 3.5/8.0. Average score (-0.7678571428571429)
# Win/lose count 0.5/2.0. Average score (-0.7931034482758621)
# Win/lose count 7.0/3.0. Average score (-0.6333333333333333)
# Win/lose count 6.0/6.0. Average score (-0.6129032258064516)
# Win/lose count 2.0/1.0. Average score (-0.5625)
# Win/lose count 0/1.0. Average score (-0.5757575757575758)
# Win/lose count 3.5/4.0. Average score (-0.5735294117647058)
# Win/lose count 2.5/3.0. Average score (-0.5714285714285714)
# Win/lose count 5.0/7.0. Average score (-0.6111111111111112)
# Win/lose count 2.5/3.0. Average score (-0.6081081081081081)
# Win/lose count 1.5/1.0. Average score (-0.5789473684210527)
# Win/lose count 1.5/2.0. Average score (-0.5769230769230769)
# Win/lose count 1.0/2.0. Average score (-0.5875)
# Win/lose count 4.5/3.0. Average score (-0.5365853658536586)
# Win/lose count 2.5/1.0. Average score (-0.4880952380952381)
# Win/lose count 1.5/2.0. Average score (-0.4883720930232558)
# Win/lose count 2.0/3.0. Average score (-0.5)
# Win/lose count 3.5/8.0. Average score (-0.5888888888888889)
# Win/lose count 1.5/6.0. Average score (-0.6739130434782609)
# Win/lose count 4.0/3.0. Average score (-0.6382978723404256)
# Win/lose count 5.0/4.0. Average score (-0.6041666666666666)
# Win/lose count 3.0/4.0. Average score (-0.6122448979591837)
# Win/lose count 3.0/3.0. Average score (-0.6)
# Final score: -0.6

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.8)
print('Test of the CNN with Temperature 0.8')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC with Temperature 0.8')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN with Temperature 0.8
# Win/lose count 14.5/1.0. Average score (13.5)
# Win/lose count 21.5/4.0. Average score (15.5)
# Win/lose count 15.0/2.0. Average score (14.666666666666666)
# Win/lose count 22.0/2.0. Average score (16.0)
# Win/lose count 29.0/4.0. Average score (17.8)
# Win/lose count 24.0/4.0. Average score (18.166666666666668)
# Win/lose count 40.5/7.0. Average score (20.357142857142858)
# Win/lose count 24.0/2.0. Average score (20.5625)
# Win/lose count 25.5/4.0. Average score (20.666666666666668)
# Win/lose count 18.5/1.0. Average score (20.35)
# Win/lose count 19.5/5.0. Average score (19.818181818181817)
# Win/lose count 17.0/2.0. Average score (19.416666666666668)
# Win/lose count 31.0/3.0. Average score (20.076923076923077)
# Win/lose count 23.5/2.0. Average score (20.178571428571427)
# Win/lose count 14.5/3.0. Average score (19.6)
# Win/lose count 36.0/3.0. Average score (20.4375)
# Win/lose count 13.5/2.0. Average score (19.91176470588235)
# Win/lose count 17.5/1.0. Average score (19.72222222222222)
# Win/lose count 25.5/1.0. Average score (19.973684210526315)
# Win/lose count 27.0/2.0. Average score (20.225)
# Win/lose count 24.5/3.0. Average score (20.285714285714285)
# Win/lose count 34.0/1.0. Average score (20.863636363636363)
# Win/lose count 17.0/5.0. Average score (20.47826086956522)
# Win/lose count 22.0/3.0. Average score (20.416666666666668)
# Win/lose count 16.0/1.0. Average score (20.2)
# Win/lose count 27.5/6.0. Average score (20.25)
# Win/lose count 31.5/4.0. Average score (20.51851851851852)
# Win/lose count 23.5/1.0. Average score (20.589285714285715)
# Win/lose count 11.5/6.0. Average score (20.06896551724138)
# Win/lose count 24.0/2.0. Average score (20.133333333333333)
# Win/lose count 10.5/3.0. Average score (19.725806451612904)
# Win/lose count 16.5/1.0. Average score (19.59375)
# Win/lose count 11.0/2.0. Average score (19.272727272727273)
# Win/lose count 23.5/0. Average score (19.397058823529413)
# Win/lose count 28.0/3.0. Average score (19.557142857142857)
# Win/lose count 24.5/3.0. Average score (19.61111111111111)
# Win/lose count 15.5/1.0. Average score (19.472972972972972)
# Win/lose count 30.0/2.0. Average score (19.69736842105263)
# Win/lose count 20.0/2.0. Average score (19.653846153846153)
# Win/lose count 31.5/5.0. Average score (19.825)
# Win/lose count 25.5/5.0. Average score (19.841463414634145)
# Win/lose count 9.0/2.0. Average score (19.535714285714285)
# Win/lose count 21.5/2.0. Average score (19.53488372093023)
# Win/lose count 25.5/4.0. Average score (19.579545454545453)
# Win/lose count 22.0/6.0. Average score (19.5)
# Win/lose count 22.0/1.0. Average score (19.532608695652176)
# Win/lose count 18.0/3.0. Average score (19.43617021276596)
# Win/lose count 27.0/1.0. Average score (19.572916666666668)
# Win/lose count 33.5/0. Average score (19.857142857142858)
# Win/lose count 15.5/1.0. Average score (19.75)
# Final score: 19.75
# Test of the FC with Temperature 0.8
# Win/lose count 18.0/5.0. Average score (13.0)
# Win/lose count 9.0/4.0. Average score (9.0)
# Win/lose count 8.0/3.0. Average score (7.666666666666667)
# Win/lose count 7.5/3.0. Average score (6.875)
# Win/lose count 11.0/1.0. Average score (7.5)
# Win/lose count 3.5/1.0. Average score (6.666666666666667)
# Win/lose count 22.0/2.0. Average score (8.571428571428571)
# Win/lose count 10.0/8.0. Average score (7.75)
# Win/lose count 8.5/2.0. Average score (7.611111111111111)
# Win/lose count 11.5/5.0. Average score (7.5)
# Win/lose count 27.5/11.0. Average score (8.318181818181818)
# Win/lose count 15.5/6.0. Average score (8.416666666666666)
# Win/lose count 16.5/10.0. Average score (8.26923076923077)
# Win/lose count 18.0/5.0. Average score (8.607142857142858)
# Win/lose count 22.5/8.0. Average score (9.0)
# Win/lose count 22.0/5.0. Average score (9.5)
# Win/lose count 6.0/1.0. Average score (9.235294117647058)
# Win/lose count 20.5/9.0. Average score (9.36111111111111)
# Win/lose count 7.5/1.0. Average score (9.210526315789474)
# Win/lose count 20.0/9.0. Average score (9.3)
# Win/lose count 10.0/2.0. Average score (9.238095238095237)
# Win/lose count 17.0/5.0. Average score (9.363636363636363)
# Win/lose count 13.0/3.0. Average score (9.391304347826088)
# Win/lose count 16.0/1.0. Average score (9.625)
# Win/lose count 14.5/2.0. Average score (9.74)
# Win/lose count 5.0/6.0. Average score (9.326923076923077)
# Win/lose count 19.5/7.0. Average score (9.444444444444445)
# Win/lose count 7.5/1.0. Average score (9.339285714285714)
# Win/lose count 11.0/5.0. Average score (9.224137931034482)
# Win/lose count 19.5/4.0. Average score (9.433333333333334)
# Win/lose count 22.5/7.0. Average score (9.629032258064516)
# Win/lose count 23.5/8.0. Average score (9.8125)
# Win/lose count 14.0/8.0. Average score (9.696969696969697)
# Win/lose count 13.5/8.0. Average score (9.573529411764707)
# Win/lose count 12.0/3.0. Average score (9.557142857142857)
# Win/lose count 9.5/0. Average score (9.555555555555555)
# Win/lose count 11.0/2.0. Average score (9.54054054054054)
# Win/lose count 18.0/4.0. Average score (9.657894736842104)
# Win/lose count 12.0/1.0. Average score (9.692307692307692)
# Win/lose count 15.0/6.0. Average score (9.675)
# Win/lose count 18.5/8.0. Average score (9.695121951219512)
# Win/lose count 16.0/4.0. Average score (9.75)
# Win/lose count 20.5/6.0. Average score (9.86046511627907)
# Win/lose count 10.5/2.0. Average score (9.829545454545455)
# Win/lose count 17.0/5.0. Average score (9.877777777777778)
# Win/lose count 13.5/5.0. Average score (9.847826086956522)
# Win/lose count 8.0/1.0. Average score (9.787234042553191)
# Win/lose count 14.5/2.0. Average score (9.84375)
# Win/lose count 8.0/1.0. Average score (9.785714285714286)
# Win/lose count 14.0/4.0. Average score (9.79)
# Final score: 9.79

# %%
HTML(display_videos('cnn_test10.mp4'))

# %%
HTML(display_videos('fc_test10.mp4'))

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %% [markdown]
# The results are a lot better and their performance relative to the random agent no longer suffers depending on the temperature. For T=0.8 we collect an enormous amount of reward (39 vs 19 on average when we do not memorize visited positions). The video shows that adding malus on visited positions indeed forces the agent to explore new areas.
# However, the downside is that the agent seems to not go back to areas explored where there are still rewards remaining.

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        print( 'epoch {0}/{1}'.format(e,epoch))
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0
        

        while not game_over:
            # The agent performs an action
            action = agent.act(state)
            

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action,train=True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)
            

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({}) | Average score til now : {}"
              .format(e, epoch, loss, win, lose, win-lose,score/(e+1)))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
class EnvironmentExploring(Environment):
    def __init__(self, *args,**kwargs):
        super(EnvironmentExploring, self).__init__( *args,**kwargs)
        self.malus_position = np.zeros((self.grid_size, self.grid_size))
        
    
    def act(self, action,train=True):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))
        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1 #modification made here

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3: #extremité droite de la grille
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1: 
            if self.x == 2: #extrémité gauche de la grille, l'agent réalise la seule action possible en x quand il tire 01
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        # take care of the malus for visited positions
        reward = 0
        if train:
            reward = -self.malus_position[self.x, self.y]
        self.malus_position[self.x, self.y] = 0.1

        reward += self.board[self.x, self.y]
        self.board[self.x, self.y] = 0 #must be set to zero, because cheese eaten disappears
        game_over = self.t > self.max_time
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:] # vision de 2 cases

        return state, reward, game_over
    
    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2) #random position of cheeses
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2) #random position of traps
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus
        
        self.malus_position = np.zeros((self.grid_size, self.grid_size))
        
        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1 #modif here
        self.board[self.x,self.y] = 0  #no starting bonus or malus
        self.t = 0

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        # gives new state of board along with previous position array

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        #we visualise new state around the new position
        #the new position corresponds to the middle array on middle line and right ie see examples below
        return state
    

    

## use those samples of code:
#In train explore:
#state, reward, game_over = env.act(action, train=True)
# Out:
# '\n## In Environment exploring:\n# You will have to change n_state to 3 because you will use one more layer!\nreward = 0\nif train:\n    reward = -self.malus_position[self.x, self.y]\nself.malus_position[self.x, self.y] = 0.1\n\nreward = reward + self.board[self.x, self.y]\n# 3 "feature" states instead of 2\nstate = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),\n                                self.board.reshape(self.grid_size, self.grid_size,1),\n                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)\n'

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.00001, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, 100, prefix='cnn_train_explore')
#HTML(display_videos('cnn_train_explore10.mp4'))
# Out:
# Model: "sequential_65"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_70 (Conv2D)           (None, 5, 5, 32)          896
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 5, 5, 64)          18496
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 5, 5, 32)          18464
# _________________________________________________________________
# flatten_65 (Flatten)         (None, 800)               0
# _________________________________________________________________
# dense_239 (Dense)            (None, 4)                 3204
# =================================================================
# Total params: 41,060
# Trainable params: 41,060
# Non-trainable params: 0
# _________________________________________________________________
# epoch 0/100
# Epoch 000/100 | Loss 0.0096 | Win/lose count 5.0/22.700000000000024 (-17.700000000000024) | Average score til now : -17.700000000000024
# epoch 1/100
# Epoch 001/100 | Loss 0.0017 | Win/lose count 4.5/25.30000000000006 (-20.80000000000006) | Average score til now : -19.250000000000043
# epoch 2/100
# Epoch 002/100 | Loss 0.0108 | Win/lose count 6.5/20.800000000000026 (-14.300000000000026) | Average score til now : -17.600000000000037
# epoch 3/100
# Epoch 003/100 | Loss 0.0161 | Win/lose count 7.0/22.700000000000003 (-15.700000000000003) | Average score til now : -17.12500000000003
# epoch 4/100
# Epoch 004/100 | Loss 0.0235 | Win/lose count 7.0/24.3000000000001 (-17.3000000000001) | Average score til now : -17.160000000000043
# epoch 5/100
# Epoch 005/100 | Loss 0.0243 | Win/lose count 12.5/20.70000000000001 (-8.20000000000001) | Average score til now : -15.666666666666705
# epoch 6/100
# Epoch 006/100 | Loss 0.0061 | Win/lose count 13.0/22.00000000000006 (-9.00000000000006) | Average score til now : -14.714285714285754
# epoch 7/100
# Epoch 007/100 | Loss 0.0141 | Win/lose count 10.5/21.50000000000003 (-11.000000000000028) | Average score til now : -14.250000000000039
# epoch 8/100
# Epoch 008/100 | Loss 0.0052 | Win/lose count 8.0/18.199999999999996 (-10.199999999999996) | Average score til now : -13.800000000000033
# epoch 9/100
# Epoch 009/100 | Loss 0.0192 | Win/lose count 7.5/20.100000000000026 (-12.600000000000026) | Average score til now : -13.680000000000032
# epoch 10/100
# Epoch 010/100 | Loss 0.0075 | Win/lose count 6.5/19.60000000000002 (-13.10000000000002) | Average score til now : -13.627272727272759
# epoch 11/100
# Epoch 011/100 | Loss 0.0027 | Win/lose count 7.5/20.400000000000023 (-12.900000000000023) | Average score til now : -13.566666666666698
# epoch 12/100
# Epoch 012/100 | Loss 0.0243 | Win/lose count 4.0/20.500000000000032 (-16.500000000000032) | Average score til now : -13.792307692307723
# epoch 13/100
# Epoch 013/100 | Loss 0.0194 | Win/lose count 11.0/20.900000000000038 (-9.900000000000038) | Average score til now : -13.514285714285746
# epoch 14/100
# Epoch 014/100 | Loss 0.0149 | Win/lose count 14.0/21.500000000000007 (-7.500000000000007) | Average score til now : -13.113333333333363
# epoch 15/100
# Epoch 015/100 | Loss 0.0159 | Win/lose count 7.0/19.600000000000016 (-12.600000000000016) | Average score til now : -13.08125000000003
# epoch 16/100
# Epoch 016/100 | Loss 0.0153 | Win/lose count 12.5/16.49999999999997 (-3.9999999999999716) | Average score til now : -12.547058823529438
# epoch 17/100
# Epoch 017/100 | Loss 0.0105 | Win/lose count 10.0/23.600000000000076 (-13.600000000000076) | Average score til now : -12.605555555555584
# epoch 18/100
# Epoch 018/100 | Loss 0.0020 | Win/lose count 13.5/17.799999999999986 (-4.2999999999999865) | Average score til now : -12.168421052631606
# epoch 19/100
# Epoch 019/100 | Loss 0.0123 | Win/lose count 16.0/18.09999999999998 (-2.09999999999998) | Average score til now : -11.665000000000024
# epoch 20/100
# Epoch 020/100 | Loss 0.0211 | Win/lose count 17.0/13.299999999999972 (3.7000000000000277) | Average score til now : -10.933333333333355
# epoch 21/100
# Epoch 021/100 | Loss 0.0093 | Win/lose count 12.0/16.399999999999967 (-4.399999999999967) | Average score til now : -10.636363636363656
# epoch 22/100
# Epoch 022/100 | Loss 0.0058 | Win/lose count 18.5/14.499999999999968 (4.000000000000032) | Average score til now : -10.000000000000018
# epoch 23/100
# Epoch 023/100 | Loss 0.0094 | Win/lose count 18.5/17.09999999999998 (1.40000000000002) | Average score til now : -9.525000000000015
# epoch 24/100
# Epoch 024/100 | Loss 0.0118 | Win/lose count 8.0/17.799999999999986 (-9.799999999999986) | Average score til now : -9.536000000000014
# epoch 25/100
# Epoch 025/100 | Loss 0.0078 | Win/lose count 18.0/16.499999999999975 (1.5000000000000249) | Average score til now : -9.111538461538474
# epoch 26/100
# Epoch 026/100 | Loss 0.0084 | Win/lose count 18.0/13.599999999999971 (4.400000000000029) | Average score til now : -8.611111111111121
# epoch 27/100
# Epoch 027/100 | Loss 0.0250 | Win/lose count 17.0/17.899999999999995 (-0.899999999999995) | Average score til now : -8.335714285714296
# epoch 28/100
# Epoch 028/100 | Loss 0.0189 | Win/lose count 11.5/13.79999999999997 (-2.2999999999999705) | Average score til now : -8.127586206896561
# epoch 29/100
# Epoch 029/100 | Loss 0.0097 | Win/lose count 12.5/19.600000000000016 (-7.100000000000016) | Average score til now : -8.093333333333343
# epoch 30/100
# Epoch 030/100 | Loss 0.0104 | Win/lose count 14.0/19.999999999999993 (-5.999999999999993) | Average score til now : -8.025806451612914
# epoch 31/100
# Epoch 031/100 | Loss 0.0286 | Win/lose count 23.0/16.99999999999999 (6.000000000000011) | Average score til now : -7.587500000000009
# epoch 32/100
# Epoch 032/100 | Loss 0.0197 | Win/lose count 20.0/16.799999999999976 (3.200000000000024) | Average score til now : -7.260606060606069
# epoch 33/100
# Epoch 033/100 | Loss 0.0143 | Win/lose count 15.0/14.299999999999972 (0.7000000000000277) | Average score til now : -7.026470588235302
# epoch 34/100
# Epoch 034/100 | Loss 0.0179 | Win/lose count 11.0/17.79999999999999 (-6.79999999999999) | Average score til now : -7.020000000000007
# epoch 35/100
# Epoch 035/100 | Loss 0.0230 | Win/lose count 21.0/14.899999999999974 (6.100000000000026) | Average score til now : -6.655555555555562
# epoch 36/100
# Epoch 036/100 | Loss 0.0195 | Win/lose count 19.0/15.599999999999971 (3.4000000000000288) | Average score til now : -6.383783783783789
# epoch 37/100
# Epoch 037/100 | Loss 0.0093 | Win/lose count 22.5/13.19999999999998 (9.30000000000002) | Average score til now : -5.971052631578952
# epoch 38/100
# Epoch 038/100 | Loss 0.0068 | Win/lose count 19.5/14.499999999999975 (5.000000000000025) | Average score til now : -5.6897435897435935
# epoch 39/100
# Epoch 039/100 | Loss 0.0254 | Win/lose count 13.5/18.099999999999998 (-4.599999999999998) | Average score til now : -5.662500000000003
# epoch 40/100
# Epoch 040/100 | Loss 0.0136 | Win/lose count 17.5/16.19999999999997 (1.3000000000000291) | Average score til now : -5.4926829268292705
# epoch 41/100
# Epoch 041/100 | Loss 0.0201 | Win/lose count 25.5/14.199999999999967 (11.300000000000033) | Average score til now : -5.092857142857144
# epoch 42/100
# Epoch 042/100 | Loss 0.0141 | Win/lose count 13.0/18.299999999999997 (-5.299999999999997) | Average score til now : -5.097674418604652
# epoch 43/100
# Epoch 043/100 | Loss 0.0163 | Win/lose count 18.0/13.399999999999972 (4.600000000000028) | Average score til now : -4.877272727272728
# epoch 44/100
# Epoch 044/100 | Loss 0.0139 | Win/lose count 10.0/17.599999999999987 (-7.599999999999987) | Average score til now : -4.937777777777778
# epoch 45/100
# Epoch 045/100 | Loss 0.0169 | Win/lose count 20.5/13.99999999999997 (6.50000000000003) | Average score til now : -4.689130434782609
# epoch 46/100
# Epoch 046/100 | Loss 0.0163 | Win/lose count 22.5/14.799999999999978 (7.700000000000022) | Average score til now : -4.425531914893616
# epoch 47/100
# Epoch 047/100 | Loss 0.0133 | Win/lose count 19.0/20.80000000000004 (-1.8000000000000398) | Average score til now : -4.370833333333334
# epoch 48/100
# Epoch 048/100 | Loss 0.0190 | Win/lose count 16.0/18.099999999999998 (-2.099999999999998) | Average score til now : -4.3244897959183675
# epoch 49/100
# Epoch 049/100 | Loss 0.0121 | Win/lose count 20.0/17.799999999999983 (2.200000000000017) | Average score til now : -4.194
# epoch 50/100
# Epoch 050/100 | Loss 0.0179 | Win/lose count 21.0/15.899999999999975 (5.1000000000000245) | Average score til now : -4.011764705882352
# epoch 51/100
# Epoch 051/100 | Loss 0.0065 | Win/lose count 25.0/15.599999999999973 (9.400000000000027) | Average score til now : -3.7538461538461525
# epoch 52/100
# Epoch 052/100 | Loss 0.0195 | Win/lose count 15.0/12.599999999999971 (2.4000000000000288) | Average score til now : -3.6377358490566016
# epoch 53/100
# Epoch 053/100 | Loss 0.0111 | Win/lose count 9.0/18.60000000000001 (-9.600000000000009) | Average score til now : -3.7481481481481467
# epoch 54/100
# Epoch 054/100 | Loss 0.0127 | Win/lose count 21.5/17.900000000000006 (3.5999999999999943) | Average score til now : -3.6145454545454534
# epoch 55/100
# Epoch 055/100 | Loss 0.0140 | Win/lose count 18.0/14.799999999999976 (3.200000000000024) | Average score til now : -3.492857142857141
# epoch 56/100
# Epoch 056/100 | Loss 0.0265 | Win/lose count 21.0/13.499999999999973 (7.500000000000027) | Average score til now : -3.299999999999998
# epoch 57/100
# Epoch 057/100 | Loss 0.0167 | Win/lose count 27.0/16.39999999999998 (10.60000000000002) | Average score til now : -3.0603448275862046
# epoch 58/100
# Epoch 058/100 | Loss 0.0272 | Win/lose count 17.5/17.599999999999998 (-0.09999999999999787) | Average score til now : -3.010169491525421
# epoch 59/100
# Epoch 059/100 | Loss 0.0206 | Win/lose count 22.5/16.699999999999985 (5.800000000000015) | Average score til now : -2.8633333333333306
# epoch 60/100
# Epoch 060/100 | Loss 0.0146 | Win/lose count 13.0/15.099999999999968 (-2.0999999999999677) | Average score til now : -2.8508196721311445
# epoch 61/100
# Epoch 061/100 | Loss 0.0128 | Win/lose count 20.5/14.699999999999976 (5.800000000000024) | Average score til now : -2.7112903225806417
# epoch 62/100
# Epoch 062/100 | Loss 0.0178 | Win/lose count 24.0/10.599999999999982 (13.400000000000018) | Average score til now : -2.455555555555552
# epoch 63/100
# Epoch 063/100 | Loss 0.0121 | Win/lose count 17.5/12.99999999999997 (4.50000000000003) | Average score til now : -2.3468749999999963
# epoch 64/100
# Epoch 064/100 | Loss 0.0104 | Win/lose count 24.5/15.899999999999975 (8.600000000000025) | Average score til now : -2.1784615384615345
# epoch 65/100
# Epoch 065/100 | Loss 0.0334 | Win/lose count 23.0/16.199999999999964 (6.800000000000036) | Average score til now : -2.042424242424238
# epoch 66/100
# Epoch 066/100 | Loss 0.0136 | Win/lose count 19.5/15.69999999999998 (3.8000000000000203) | Average score til now : -1.9552238805970104
# epoch 67/100
# Epoch 067/100 | Loss 0.0219 | Win/lose count 18.0/17.699999999999996 (0.30000000000000426) | Average score til now : -1.922058823529407
# epoch 68/100
# Epoch 068/100 | Loss 0.0144 | Win/lose count 19.5/13.399999999999972 (6.100000000000028) | Average score til now : -1.8057971014492704
# epoch 69/100
# Epoch 069/100 | Loss 0.0330 | Win/lose count 22.5/13.399999999999972 (9.100000000000028) | Average score til now : -1.6499999999999948
# epoch 70/100
# Epoch 070/100 | Loss 0.0310 | Win/lose count 23.0/15.49999999999997 (7.50000000000003) | Average score til now : -1.5211267605633747
# epoch 71/100
# Epoch 071/100 | Loss 0.0237 | Win/lose count 21.0/15.499999999999968 (5.500000000000032) | Average score til now : -1.4236111111111052
# epoch 72/100
# Epoch 072/100 | Loss 0.0174 | Win/lose count 19.0/14.799999999999974 (4.200000000000026) | Average score til now : -1.3465753424657472
# epoch 73/100
# Epoch 073/100 | Loss 0.0138 | Win/lose count 24.5/20.800000000000022 (3.699999999999978) | Average score til now : -1.2783783783783726
# epoch 74/100
# Epoch 074/100 | Loss 0.0174 | Win/lose count 23.5/12.99999999999997 (10.50000000000003) | Average score til now : -1.1213333333333273
# epoch 75/100
# Epoch 075/100 | Loss 0.0326 | Win/lose count 10.0/18.500000000000004 (-8.500000000000004) | Average score til now : -1.2184210526315729
# epoch 76/100
# Epoch 076/100 | Loss 0.0320 | Win/lose count 22.5/18.199999999999996 (4.300000000000004) | Average score til now : -1.1467532467532406
# epoch 77/100
# Epoch 077/100 | Loss 0.0158 | Win/lose count 21.0/14.799999999999967 (6.200000000000033) | Average score til now : -1.0525641025640962
# epoch 78/100
# Epoch 078/100 | Loss 0.0209 | Win/lose count 20.5/14.199999999999973 (6.300000000000027) | Average score til now : -0.9594936708860693
# epoch 79/100
# Epoch 079/100 | Loss 0.0346 | Win/lose count 23.5/14.29999999999997 (9.20000000000003) | Average score til now : -0.832499999999993
# epoch 80/100
# Epoch 080/100 | Loss 0.0162 | Win/lose count 20.5/17.099999999999977 (3.4000000000000234) | Average score til now : -0.7802469135802398
# epoch 81/100
# Epoch 081/100 | Loss 0.0375 | Win/lose count 22.0/15.19999999999998 (6.80000000000002) | Average score til now : -0.6878048780487732
# epoch 82/100
# Epoch 082/100 | Loss 0.0263 | Win/lose count 21.0/13.999999999999977 (7.000000000000023) | Average score til now : -0.5951807228915588
# epoch 83/100
# Epoch 083/100 | Loss 0.0357 | Win/lose count 14.0/16.899999999999974 (-2.8999999999999737) | Average score til now : -0.62261904761904
# epoch 84/100
# Epoch 084/100 | Loss 0.0191 | Win/lose count 19.0/14.599999999999968 (4.400000000000032) | Average score til now : -0.563529411764698
# epoch 85/100
# Epoch 085/100 | Loss 0.0254 | Win/lose count 20.5/14.99999999999997 (5.50000000000003) | Average score til now : -0.4930232558139453
# epoch 86/100
# Epoch 086/100 | Loss 0.0149 | Win/lose count 17.5/15.599999999999971 (1.9000000000000288) | Average score til now : -0.46551724137930195
# epoch 87/100
# Epoch 087/100 | Loss 0.0155 | Win/lose count 20.5/14.599999999999971 (5.900000000000029) | Average score til now : -0.3931818181818096
# epoch 88/100
# Epoch 088/100 | Loss 0.0361 | Win/lose count 24.5/13.399999999999974 (11.100000000000026) | Average score til now : -0.26404494382021587
# epoch 89/100
# Epoch 089/100 | Loss 0.0136 | Win/lose count 23.5/14.399999999999975 (9.100000000000025) | Average score til now : -0.159999999999991
# epoch 90/100
# Epoch 090/100 | Loss 0.0172 | Win/lose count 20.5/11.799999999999978 (8.700000000000022) | Average score til now : -0.06263736263735349
# epoch 91/100
# Epoch 091/100 | Loss 0.0287 | Win/lose count 21.0/17.299999999999976 (3.700000000000024) | Average score til now : -0.021739130434773303
# epoch 92/100
# Epoch 092/100 | Loss 0.0209 | Win/lose count 20.0/13.999999999999973 (6.000000000000027) | Average score til now : 0.04301075268818154
# epoch 93/100
# Epoch 093/100 | Loss 0.0271 | Win/lose count 19.0/16.199999999999978 (2.800000000000022) | Average score til now : 0.07234042553192452
# epoch 94/100
# Epoch 094/100 | Loss 0.0384 | Win/lose count 24.0/13.799999999999972 (10.200000000000028) | Average score til now : 0.17894736842106243
# epoch 95/100
# Epoch 095/100 | Loss 0.0335 | Win/lose count 25.0/15.09999999999998 (9.90000000000002) | Average score til now : 0.2802083333333432
# epoch 96/100
# Epoch 096/100 | Loss 0.0369 | Win/lose count 24.5/15.39999999999997 (9.10000000000003) | Average score til now : 0.3711340206185668
# epoch 97/100
# Epoch 097/100 | Loss 0.0298 | Win/lose count 22.0/17.699999999999974 (4.300000000000026) | Average score til now : 0.4112244897959286
# epoch 98/100
# Epoch 098/100 | Loss 0.0212 | Win/lose count 22.0/14.599999999999968 (7.400000000000032) | Average score til now : 0.4818181818181923
# epoch 99/100
# Epoch 099/100 | Loss 0.0398 | Win/lose count 26.5/15.199999999999982 (11.300000000000018) | Average score til now : 0.5900000000000106

# %%
# Evaluation
agent_cnn.load(name_weights='cnn_train_exploremodel.h5',name_model='cnn_train_exploremodel.json')
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
test(agent,env,epochs_test,prefix='cnn_train_explore')
#HTML(display_videos('cnn_test_explore10.mp4'))
# Out:
# Win/lose count 25.0/19.6. Average score (5.399999999999999)
# Win/lose count 21.5/17.99999999999999. Average score (4.450000000000005)
# Win/lose count 20.5/12.299999999999976. Average score (5.700000000000011)
# Win/lose count 22.0/18.0. Average score (5.275000000000009)
# Win/lose count 21.5/15.29999999999998. Average score (5.4600000000000115)
# Win/lose count 14.5/16.899999999999977. Average score (4.150000000000013)
# Win/lose count 29.5/16.099999999999973. Average score (5.471428571428587)
# Win/lose count 22.5/17.599999999999984. Average score (5.400000000000015)
# Win/lose count 22.0/17.8. Average score (5.26666666666668)
# Win/lose count 20.0/12.699999999999978. Average score (5.470000000000015)
# Win/lose count 21.5/15.499999999999975. Average score (5.518181818181834)
# Win/lose count 26.0/14.399999999999979. Average score (6.025000000000016)
# Win/lose count 20.5/17.59999999999999. Average score (5.7846153846154005)
# Win/lose count 21.0/15.199999999999976. Average score (5.785714285714302)
# Win/lose count 20.5/16.899999999999984. Average score (5.6400000000000166)
# Win/lose count 20.5/18.0. Average score (5.443750000000016)
# Win/lose count 13.5/20.20000000000001. Average score (4.729411764705896)
# Win/lose count 23.5/14.89999999999997. Average score (4.944444444444459)
# Win/lose count 22.0/16.899999999999988. Average score (4.952631578947383)
# Win/lose count 29.0/14.599999999999973. Average score (5.425000000000014)
# Win/lose count 21.0/16.09999999999997. Average score (5.4000000000000155)
# Win/lose count 22.0/19.999999999999993. Average score (5.24545454545456)
# Win/lose count 12.0/16.59999999999997. Average score (4.817391304347842)
# Win/lose count 24.0/19.00000000000002. Average score (4.8250000000000135)
# Win/lose count 24.5/19.80000000000001. Average score (4.820000000000013)
# Win/lose count 19.5/15.399999999999965. Average score (4.7923076923077055)
# Win/lose count 23.5/17.29999999999999. Average score (4.844444444444458)
# Win/lose count 25.5/14.299999999999976. Average score (5.071428571428585)
# Win/lose count 17.5/19.500000000000014. Average score (4.827586206896566)
# Win/lose count 12.0/19.999999999999986. Average score (4.400000000000014)
# Win/lose count 27.0/16.59999999999998. Average score (4.593548387096788)
# Win/lose count 20.5/18.600000000000005. Average score (4.509375000000014)
# Win/lose count 27.0/14.49999999999997. Average score (4.751515151515165)
# Win/lose count 23.5/14.599999999999975. Average score (4.8735294117647205)
# Win/lose count 28.0/13.599999999999977. Average score (5.145714285714301)
# Win/lose count 25.0/14.19999999999998. Average score (5.302777777777793)
# Win/lose count 18.0/17.299999999999986. Average score (5.178378378378394)
# Win/lose count 18.0/19.099999999999973. Average score (5.013157894736858)
# Win/lose count 22.5/15.399999999999975. Average score (5.066666666666682)
# Win/lose count 24.5/14.299999999999976. Average score (5.195000000000016)
# Win/lose count 27.5/22.70000000000002. Average score (5.185365853658552)
# Win/lose count 27.5/8.799999999999986. Average score (5.507142857142872)
# Win/lose count 20.5/19.90000000000002. Average score (5.393023255813968)
# Win/lose count 19.0/15.999999999999964. Average score (5.338636363636378)
# Win/lose count 25.5/16.699999999999978. Average score (5.415555555555571)
# Win/lose count 22.5/13.799999999999976. Average score (5.486956521739145)
# Win/lose count 22.0/14.399999999999967. Average score (5.531914893617036)
# Win/lose count 23.5/14.799999999999978. Average score (5.5979166666666815)
# Win/lose count 21.5/16.299999999999976. Average score (5.589795918367363)
# Win/lose count 22.5/13.29999999999998. Average score (5.662000000000017)
# Final score: 5.662000000000017

# %%
# Evaluation
agent_cnn.load(name_weights='cnn_train_exploremodel.h5',name_model='cnn_train_exploremodel.json')
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.8)
test(agent,env,epochs_test,prefix='cnn_train_explore')
#HTML(display_videos('cnn_test_explore10.mp4'))
# Out:
# Win/lose count 56.0/11.799999999999985. Average score (44.20000000000002)
# Win/lose count 41.5/12.499999999999972. Average score (36.60000000000002)
# Win/lose count 59.5/9.599999999999985. Average score (41.03333333333335)
# Win/lose count 40.0/15.99999999999997. Average score (36.77500000000003)
# Win/lose count 60.0/15.799999999999981. Average score (38.260000000000026)
# Win/lose count 54.5/13.399999999999975. Average score (38.733333333333356)
# Win/lose count 61.0/10.699999999999987. Average score (40.38571428571431)
# Win/lose count 48.5/17.09999999999999. Average score (39.262500000000024)
# Win/lose count 56.5/15.399999999999979. Average score (39.46666666666669)
# Win/lose count 58.0/15.199999999999983. Average score (39.800000000000026)
# Win/lose count 61.5/13.399999999999983. Average score (40.554545454545476)
# Win/lose count 57.0/17.299999999999997. Average score (40.483333333333356)
# Win/lose count 49.0/15.19999999999998. Average score (39.96923076923079)
# Win/lose count 58.0/10.19999999999998. Average score (40.52857142857145)
# Win/lose count 58.0/14.499999999999984. Average score (40.72666666666669)
# Win/lose count 58.5/16.19999999999998. Average score (40.825000000000024)
# Win/lose count 55.0/12.599999999999975. Average score (40.91764705882355)
# Win/lose count 62.0/11.599999999999985. Average score (41.444444444444464)
# Win/lose count 49.0/13.59999999999998. Average score (41.1263157894737)
# Win/lose count 46.5/17.799999999999983. Average score (40.50500000000002)
# Win/lose count 56.0/14.599999999999977. Average score (40.547619047619065)
# Win/lose count 53.0/12.999999999999972. Average score (40.52272727272729)
# Win/lose count 63.0/12.199999999999987. Average score (40.96956521739132)
# Win/lose count 57.0/16.499999999999986. Average score (40.95000000000002)
# Win/lose count 52.5/11.09999999999998. Average score (40.96800000000002)
# Win/lose count 26.5/15.499999999999961. Average score (39.81538461538464)
# Win/lose count 45.5/18.69999999999998. Average score (39.33333333333335)
# Win/lose count 55.5/11.799999999999983. Average score (39.489285714285735)
# Win/lose count 48.0/11.699999999999978. Average score (39.3793103448276)
# Win/lose count 56.0/9.299999999999985. Average score (39.62333333333335)
# Win/lose count 55.5/10.299999999999986. Average score (39.80322580645163)
# Win/lose count 40.5/15.29999999999997. Average score (39.34687500000002)
# Win/lose count 58.0/14.999999999999979. Average score (39.457575757575775)
# Win/lose count 47.5/13.299999999999969. Average score (39.302941176470604)
# Win/lose count 53.5/14.999999999999988. Average score (39.280000000000015)
# Win/lose count 55.5/20.200000000000017. Average score (39.16944444444446)
# Win/lose count 54.5/15.299999999999978. Average score (39.17027027027029)
# Win/lose count 59.5/13.899999999999984. Average score (39.33947368421054)
# Win/lose count 60.5/14.599999999999978. Average score (39.507692307692324)
# Win/lose count 51.0/13.599999999999975. Average score (39.45500000000002)
# Win/lose count 64.0/14.09999999999998. Average score (39.709756097561)
# Win/lose count 47.0/16.099999999999973. Average score (39.50000000000002)
# Win/lose count 62.0/12.59999999999998. Average score (39.730232558139555)
# Win/lose count 61.0/11.99999999999998. Average score (39.940909090909116)
# Win/lose count 45.0/15.89999999999998. Average score (39.70000000000002)
# Win/lose count 59.5/11.299999999999983. Average score (39.88478260869567)
# Win/lose count 46.0/13.399999999999972. Average score (39.729787234042576)
# Win/lose count 52.0/14.599999999999971. Average score (39.68125000000003)
# Win/lose count 37.5/16.899999999999988. Average score (39.2918367346939)
# Win/lose count 61.5/11.79999999999998. Average score (39.50000000000002)
# Final score: 39.50000000000002

# %%
display2('cnn_test_explore90.mp4')

# %% [markdown]
# ***
